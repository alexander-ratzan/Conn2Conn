# %% [markdown]
# # Test LatentAttnTranslation
#
# Lightweight local dev notebook for the `LatentAttnTranslation` baseline.

# %%
import importlib
import main
import data
import models.config
import models.latent_attn_translation
from main import Sim

# Ensure the latest code is loaded in the interactive notebook
importlib.reload(models)
importlib.reload(models.latent_attn_translation)
importlib.reload(models.config)
importlib.reload(main)
importlib.reload(data)
# Out:
# <module 'data' (namespace) from ['/scratch/asr655/neuroinformatics/Conn2Conn/data', '/scratch/asr655/neuroinformatics/Conn2Conn/data']>

# %%
# Small defaults for quick local iteration
config_override = {
    "model": {
        "n_components_pca": 32,
        "n_components_pls": 8,
        "attn_dim": 8,
        "value_dim": 8,
        "readout_type": "mlp",
        "readout_hidden_dim": 16,
        "attention_dropout": 0.0,
        "reg": 1e-5,
    },
    "trainer": {
        "max_epochs": 100,
        "batch_size": 128,
        "lr": 1e-3,
        "loss_type": "latent_mse",
    },
}

sim = Sim(
    model_name="LatentAttnTranslation",
    config_overrides=config_override,
    source="SC",
    target="FC",
    parcellation='Glasser',
    shuffle_seed=0,
    data_load_mode="precomputed",
)
# Out:
# /ext3/miniforge3/lib/python3.12/site-packages/numpy/lib/_function_base_impl.py:3065: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /ext3/miniforge3/lib/python3.12/site-packages/numpy/lib/_function_base_impl.py:3066: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]

# %%
# config_override = {
#     "model": {
#         "n_components_pca": 256,
#         "n_components_pls": 16,
#         "token_embedding_type": "pls",
#         "learnable_pls_projection": False,
#         "token_embedding_dim": 16,
#         "attn_dim": 16,
#         "value_dim": 32,
#         "attention_dropout": 0.0,
        "residual_gain_init": 1e-3,
#         "reg": 1e-6,
#     },
#     "trainer": {
#         "max_epochs": 100,
#         "batch_size": 128,
#         "lr": 1e-2,
#         "loss_type": "latent_mse",
#     },
# }

config_override = {
    "model": {
        "n_components_pca": 128,
        "n_components_pls": 64,
        "token_embedding_type": "pls",
        "learnable_pls_projection": True,
        "attn_dim": 64,
        "value_dim": 64,
        "attention_dropout": 0.0,
        "residual_gain_init": 1e-3,
        "reg": 1.0e-6,
    },
    "trainer": {
        "max_epochs": 150,
        "batch_size": 128,
        "lr": 1e-2,
        "loss_type": "latent_weighted_mse",
    },
}

run_out = sim._run_learned_single(
    mode="dev",
    save_checkpoint=False,
    config_override=config_override,
)
run_out["test_metrics"]["base_metrics"]
# Out:
# /ext3/miniforge3/lib/python3.12/site-packages/sklearn/cross_decomposition/_pls.py:104: ConvergenceWarning: Maximum number of iterations reached
#   warnings.warn("Maximum number of iterations reached", ConvergenceWarning)
# LatentAttnTranslation init | src=SC tgt=FC | d_source=64620 d_target=64620 | k=128 | token_embedding_type=learned token_embedding_dim=16 | learnable_pls_projection=False | attn_dim=64 value_dim=64 | readout_type=mlp readout_hidden_dim=16 | zscore_pca_scores=False
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# ...

# %%
run_out = sim._run_learned_single(
    mode="prod",
    save_checkpoint=False,
    config_override=config_override,
)
run_out["test_metrics"]["base_metrics"]
