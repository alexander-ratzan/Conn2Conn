# %% [markdown]
# # Test Chen2024 GCN
#
# Lightweight local dev notebook for the `Chen2024GCN` baseline.

# %%
import importlib
import main
import data
from main import Sim

# Ensure the latest code is loaded in the interactive notebook
importlib.reload(main)
importlib.reload(data)
# Out:
# <module 'data' (namespace) from ['/scratch/asr655/neuroinformatics/Conn2Conn/data', '/scratch/asr655/neuroinformatics/Conn2Conn/data']>

# %%
# Small defaults for quick local iteration
config_override = {
    "model": {
        "layer_num": 2,
        "conv_dim": 64,
        "dnn_dim": 32,
        "node_feature_type": "identity",
        "reg": 1e-4,
    },
    "trainer": {
        "max_epochs": 20,
        "batch_size": 8,
        "lr": 1e-3,
        "loss_type": "mse",
    },
}

sim = Sim(
    model_name="Chen2024GCN",
    config_overrides=config_override,
    source="SC",
    target="FC",
    parcellation='Glasser',
    shuffle_seed=0,
    data_load_mode="precomputed",
)
# Out:
# /ext3/miniforge3/lib/python3.12/site-packages/numpy/lib/_function_base_impl.py:3065: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /ext3/miniforge3/lib/python3.12/site-packages/numpy/lib/_function_base_impl.py:3066: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]

# %%
# Small defaults for quick local iteration
config_override = {
    "model": {
        "layer_num": 2,
        "conv_dim": 128,
        "dnn_dim": 64,
        "node_feature_type": "identity",
        "reg": 1e-5,
    },
    "trainer": {
        "max_epochs": 1000,
        "lr": 2e-3,
    },
}

run_out = sim._run_learned_single(
    mode="dev",
    save_checkpoint=False,
    config_override=config_override,
)
run_out["test_metrics"]["base_metrics"]
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# 💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
# /home/asr655/.local/lib/python3.12/site-packages/lightning/pytorch/callbacks/model_checkpoint.py:881: Checkpoint directory /scratch/asr655/neuroinformatics/Conn2Conn/checkpoints exists and is not empty.
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
#
#   | Name    | Type        | Params | Mode  | FLOPs
# --------------------------------------------------------
# 0 | model   | Chen2024GCN | 79.2 K | train | 0
# 1 | loss_fn | MSELoss     | 0      | train | 0
# --------------------------------------------------------
# 79.2 K    Trainable params
# 0         Non-trainable params
# 79.2 K    Total params
# 0.317     Total estimated model params size (MB)
# 16        Modules in train mode
# 0         Modules in eval mode
# 0         Total Flops
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# /home/asr655/.local/lib/python3.12/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:434: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=127` in the `DataLoader` to improve performance.
# /home/asr655/.local/lib/python3.12/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:434: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=127` in the `DataLoader` to improve performance.
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Detected KeyboardInterrupt, attempting graceful shutdown ...
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
# /ext3/miniforge3/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3707: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
# Error in callback <bound method _WandbInit._post_run_cell_hook of <wandb.sdk.wandb_init._WandbInit object at 0x7f36e8462ab0>> (for post_run_cell), with arguments args (<ExecutionResult object at 7f36e8080860, execution_count=4 error_before_exec=None error_in_exec=1 info=<ExecutionInfo object at 7f36e80809e0, raw_cell="# Small defaults for quick local iteration
# config_.." transformed_cell="# Small defaults for quick local iteration
# config_.." store_history=True silent=False shell_futures=True cell_id=vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a22746f7263682d636f6d70757465227d/scratch/asr655/neuroinformatics/Conn2Conn/test_chen2024_model.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D> result=None>,),kwargs {}:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# File ~/.local/lib/python3.12/site-packages/wandb/sdk/wandb_init.py:607, in _WandbInit._post_run_cell_hook(self, *args, **kwargs)
#     604     return
#     606 self._logger.info("resuming backend")
# --> 607 self.backend.interface.publish_resume()
#
# File ~/.local/lib/python3.12/site-packages/wandb/sdk/interface/interface.py:812, in InterfaceBase.publish_resume(self)
#     810 def publish_resume(self) -> None:
#     811     resume = pb.ResumeRequest()
# --> 812     self._publish_resume(resume)
#
# File ~/.local/lib/python3.12/site-packages/wandb/sdk/interface/interface_shared.py:336, in InterfaceShared._publish_resume(self, resume)
#     334 def _publish_resume(self, resume: pb.ResumeRequest) -> None:
#     335     rec = self._make_request(resume=resume)
# --> 336     self._publish(rec)
#
# File ~/.local/lib/python3.12/site-packages/wandb/sdk/interface/interface_sock.py:46, in InterfaceSock._publish(self, record, nowait)
#      44     self._asyncer.run_soon(lambda: self._client.publish(request))
#      45 else:
# ---> 46     self._asyncer.run(lambda: self._client.publish(request))
#
# File ~/.local/lib/python3.12/site-packages/wandb/sdk/lib/asyncio_manager.py:137, in AsyncioManager.run(self, fn)
#     134 future = self._schedule(fn, daemon=False)
#     136 try:
# --> 137     return future.result()
#     139 except concurrent.futures.CancelledError:
#     140     raise RunCancelledError from None
#
# File /ext3/miniforge3/lib/python3.12/concurrent/futures/_base.py:456, in result(self, timeout)
#
# File /ext3/miniforge3/lib/python3.12/concurrent/futures/_base.py:401, in __get_result(self)
#
# File ~/.local/lib/python3.12/site-packages/wandb/sdk/lib/asyncio_manager.py:220, in AsyncioManager._wrap(self, fn, daemon, name)
#     217     if name and (task := asyncio.current_task()):
#     218         task.set_name(name)
# --> 220     return await fn()
#     221 finally:
#     222     if not daemon:
#
# File ~/.local/lib/python3.12/site-packages/wandb/sdk/lib/service/service_client.py:45, in ServiceClient.publish(self, request)
#      43 async def publish(self, request: spb.ServerRequest) -> None:
#      44     """Send a request without waiting for a response."""
# ---> 45     await self._send_server_request(request)
#
# File ~/.local/lib/python3.12/site-packages/wandb/sdk/lib/service/service_client.py:87, in ServiceClient._send_server_request(self, request)
#      84 self._writer.write(data)
#      86 try:
# ---> 87     await self._drain_writer()
#      88 except Exception as e:
#      89     self._broken_exc = e
#
# File ~/.local/lib/python3.12/site-packages/wandb/sdk/lib/service/service_client.py:96, in ServiceClient._drain_writer(self)
#      94 """Wait for the socket's flow control."""
#      95 if sys.version_info >= (3, 10):
# ---> 96     await self._writer.drain()
#      97     return
#      99 # Prior to 3.10, drain() incorrectly raised an AssertionError when the
#     100 # write buffer was maxed out if called from more than one async task.
#
# File /ext3/miniforge3/lib/python3.12/asyncio/streams.py:392, in drain(self)
#
# File /ext3/miniforge3/lib/python3.12/asyncio/streams.py:166, in _drain_helper(self)
#
# ConnectionResetError: Connection lost

# %%
# Small defaults for quick local iteration
config_override = {
    "model": {
        "layer_num": 2,
        "conv_dim": 128,
        "dnn_dim": 64,
        "node_feature_type": "identity",
        "reg": 1e-5,
    },
    "trainer": {
        "max_epochs": 500,
        "lr": 3e-3,
    },
}

run_out = sim._run_learned_single(
    mode="prod",
    save_checkpoint=False,
    config_override=config_override,
)
run_out["test_metrics"]["base_metrics"]
# Out:
# wandb: WARNING The anonymous setting has no effect and will be removed in a future version.
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /home/asr655/.netrc.
# wandb: Currently logged in as: asratzan (alexander-ratzan-new-york-university) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>/scratch/asr655/neuroinformatics/Conn2Conn/results/wandb/run-20260320_174458-83bg2cop</code>
# Syncing run <strong><a href='https://wandb.ai/alexander-ratzan-new-york-university/conn2conn/runs/83bg2cop' target="_blank">Chen2024GCN_prod</a></strong> to <a href='https://wandb.ai/alexander-ratzan-new-york-university/conn2conn' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/alexander-ratzan-new-york-university/conn2conn' target="_blank">https://wandb.ai/alexander-ratzan-new-york-university/conn2conn</a>
#  View run at <a href='https://wandb.ai/alexander-ratzan-new-york-university/conn2conn/runs/83bg2cop' target="_blank">https://wandb.ai/alexander-ratzan-new-york-university/conn2conn/runs/83bg2cop</a>
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# 💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
# /ext3/miniforge3/lib/python3.12/site-packages/torch/__init__.py:1551: UserWarning: Please use the new API settings to control TF32 behavior, such as torch.backends.cudnn.conv.fp32_precision = 'tf32' or torch.backends.cuda.matmul.fp32_precision = 'ieee'. Old settings, e.g, torch.backends.cuda.matmul.allow_tf32 = True, torch.backends.cudnn.allow_tf32 = True, allowTF32CuDNN() and allowTF32CuBLAS() will be deprecated after Pytorch 2.9. Please see https://pytorch.org/docs/main/notes/cuda.html#tensorfloat-32-tf32-on-ampere-and-later-devices (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:80.)
#   return _C._get_float32_matmul_precision()
# You are using a CUDA device ('NVIDIA L40S') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
#
#   | Name    | Type        | Params | Mode  | FLOPs
# --------------------------------------------------------
# 0 | model   | Chen2024GCN | 79.2 K | train | 0
# 1 | loss_fn | MSELoss     | 0      | train | 0
# --------------------------------------------------------
# 79.2 K    Trainable params
# 0         Non-trainable params
# 79.2 K    Total params
# 0.317     Total estimated model params size (MB)
# 16        Modules in train mode
# 0         Modules in eval mode
# 0         Total Flops
# /home/asr655/.local/lib/python3.12/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:434: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=127` in the `DataLoader` to improve performance.
# /home/asr655/.local/lib/python3.12/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:434: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=127` in the `DataLoader` to improve performance.
# `Trainer.fit` stopped: `max_epochs=500` reached.
# ================================================================================
# Training complete!
# ================================================================================
# Number of unique demographic categories: 14
# Top-1 accuracy: 0.015  (3 of 195 subjects had rank 1) (chance=0.005)
# Average rank percentile: 0.568 (chance=0.5)
# Number of unique demographic categories: 14
# Top-1 accuracy: 0.010  (2 of 195 subjects had rank 1) (chance=0.005)
# Average rank percentile: 0.619 (chance=0.5)
# returned noise_preds [[ 0.10335521  0.27345122  0.79338547 ...  0.07845211  0.10779614
#    0.35724186]
#  [ 0.1919979   0.47149277  0.6724819  ... -0.13729251 -0.09331813
#    0.66529665]
#  [ 0.3631451   0.63926478  0.88444692 ... -0.01370378  0.1294217
#    0.39960487]
#  ...
#  [-0.08238107  0.82869741  1.07752772 ... -0.06908563 -0.00440757
#    0.40327927]
#  [ 0.12395491  0.68586381  0.6269891  ... -0.12566293  0.16673286
#    0.53747594]
#  [ 0.05569953  0.62698837  0.69579952 ... -0.09271121  0.09947315
#    0.36341394]]
# Identifiability Summary:
# ======================================================================
# Condition    r_intra    r_inter    d          t          p            Cohen d
# ----------------------------------------------------------------------
# pFC          0.7654     0.7619     0.0035     3.22       1.48e-03     0.23
# Mean eFC     0.8390     0.8390     0.0000     0.90       3.71e-01     0.06
# Null         0.6982     0.6980     0.0001     1.13       2.59e-01     0.08
# ======================================================================
# returned noise_preds [[ 0.10335521  0.27345122  0.79338547 ...  0.07845211  0.10779614
#    0.35724186]
#  [ 0.1919979   0.47149277  0.6724819  ... -0.13729251 -0.09331813
#    0.66529665]
#  [ 0.3631451   0.63926478  0.88444692 ... -0.01370378  0.1294217
#    0.39960487]
#  ...
#  [-0.08238107  0.82869741  1.07752772 ... -0.06908563 -0.00440757
#    0.40327927]
#  [ 0.12395491  0.68586381  0.6269891  ... -0.12566293  0.16673286
#    0.53747594]
#  [ 0.05569953  0.62698837  0.69579952 ... -0.09271121  0.09947315
#    0.36341394]]
# Identifiability Summary:
# ======================================================================
# Condition    r_intra    r_inter    d          t          p            Cohen d
# ----------------------------------------------------------------------
# pFC          0.0107     -0.0049    0.0156     5.74       3.53e-08     0.41
# Null         0.0004     -0.0001    0.0005     1.35       1.78e-01     0.10
# ======================================================================
# Running Hungarian matching analysis for n=2 to 75 (step=10) with M=1000 iterations...
#   n=2: pFC=70.0%, Noise=54.4%, Permute=50.0%
#   n=12: pFC=17.3%, Noise=10.5%, Permute=8.4%
#   n=22: pFC=11.3%, Noise=6.2%, Permute=4.7%
#   n=32: pFC=8.6%, Noise=4.7%, Permute=3.3%
#   n=42: pFC=7.1%, Noise=3.6%, Permute=2.4%
#   n=52: pFC=5.8%, Noise=3.1%, Permute=2.0%
#   n=62: pFC=5.4%, Noise=2.7%, Permute=1.7%
#   n=72: pFC=4.7%, Noise=2.3%, Permute=1.3%
# FDR-corrected significance (alpha=0.05):
#   pFC vs Null (permute): 8/8 sample sizes significant
#   pFC vs Null (noise): 8/8 sample sizes significant
# Running Hungarian matching analysis for n=2 to 75 (step=10) with M=1000 iterations...
#   n=2: pFC=70.7%, Noise=52.8%, Permute=49.5%
#   n=12: pFC=16.2%, Noise=10.6%, Permute=8.5%
#   n=22: pFC=10.2%, Noise=6.3%, Permute=4.5%
#   n=32: pFC=8.0%, Noise=4.8%, Permute=3.2%
#   n=42: pFC=6.5%, Noise=3.8%, Permute=2.4%
#   n=52: pFC=5.4%, Noise=3.3%, Permute=2.0%
#   n=62: pFC=5.0%, Noise=2.9%, Permute=1.6%
#   n=72: pFC=4.4%, Noise=2.6%, Permute=1.4%
# FDR-corrected significance (alpha=0.05):
#   pFC vs Null (permute): 8/8 sample sizes significant
#   pFC vs Null (noise): 8/8 sample sizes significant
# {'mse': np.float32(0.018803755),
#  'r2': np.float32(-0.4224152),
#  'pearson': np.float32(0.76541615),
#  'demeaned_pearson': np.float32(0.010730857),
#  'avg_rank': np.float64(0.5733859303090072),
#  'top1_acc': np.float64(0.015384615384615385)}
